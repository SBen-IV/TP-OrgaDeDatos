# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style="whitegrid")

# %%
labels = pd.read_csv("../train_labels.csv")
values = pd.read_csv("../train_values.csv")

# %%
labels
# Out:
#         building_id  damage_grade
# 0            802906             3
# 1             28830             2
# 2             94947             3
# 3            590882             2
# 4            201944             3
# ...             ...           ...
# 260596       688636             2
# 260597       669485             3
# 260598       602512             3
# 260599       151409             2
# 260600       747594             3
#
# [260601 rows x 2 columns]

# %%
values
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %% [markdown]
# ## Análisis de `has_secondary_use`

# %%
cols = list(values.columns)
new_cols = ["building_id"]

for col in cols:
    if (col.startswith("has_secondary_use")):
        new_cols.append(col)

new_cols
# Out:
# ['building_id',
#  'has_secondary_use',
#  'has_secondary_use_agriculture',
#  'has_secondary_use_hotel',
#  'has_secondary_use_rental',
#  'has_secondary_use_institution',
#  'has_secondary_use_school',
#  'has_secondary_use_industry',
#  'has_secondary_use_health_post',
#  'has_secondary_use_gov_office',
#  'has_secondary_use_use_police',
#  'has_secondary_use_other']

# %%
values_secondary_use = values[new_cols]
values_secondary_use.set_index("building_id", inplace=True)

values_secondary_use
# Out:
#              has_secondary_use  has_secondary_use_agriculture  \
# building_id
# 802906                       0                              0
# 28830                        0                              0
# 94947                        0                              0
# 590882                       0                              0
# 201944                       0                              0
# ...                        ...                            ...
# 688636                       0                              0
# 669485                       0                              0
# 602512                       0                              0
# 151409                       0                              0
# 747594                       0                              0
#
#              has_secondary_use_hotel  has_secondary_use_rental  \
# building_id
# 802906                             0                         0
# 28830                              0                         0
# ...

# %%
values_has_secondary_use = values_secondary_use[values_secondary_use['has_secondary_use'] == 1]
values_has_secondary_use
# Out:
#              has_secondary_use  has_secondary_use_agriculture  \
# building_id
# 333020                       1                              1
# 793397                       1                              1
# 973909                       1                              1
# 440102                       1                              0
# 552720                       1                              1
# ...                        ...                            ...
# 977263                       1                              1
# 317439                       1                              1
# 603159                       1                              1
# 560805                       1                              1
# 226421                       1                              1
#
#              has_secondary_use_hotel  has_secondary_use_rental  \
# building_id
# 333020                             0                         0
# 793397                             0                         0
# ...

# %%
values_has_secondary_use.shape[0] / values_secondary_use.shape[0] * 100
# Out:
# 11.187984696912137

# %% [markdown]
# ### Solo un 11% tiene secondary use
