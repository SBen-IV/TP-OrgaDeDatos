# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Train

# %%
train = pd.read_csv('../Train/train_set_geo_level_sum_base.csv')

train.head(10)
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
# 5               8             558            6089                    2   10
# 6               9             475           12066                    2   25
# 7              20             323           12236                    2    0
# 8               0             757            7219                    2   15
# 9              26             886             994                    1    0
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# ...

# %%
pos = len(train.columns) - 1

train.insert(pos, "area_per_height", train['area_percentage'] * train['height_percentage'])

train
# Out:
#         geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                    6             487           12198                    2
# 1                    8             900            2812                    2
# 2                   21             363            8973                    2
# 3                   22             418           10694                    2
# 4                   11             131            1488                    3
# ...                ...             ...             ...                  ...
# 260596              25            1335            1621                    1
# 260597              17             715            2060                    2
# 260598              17              51            8163                    3
# 260599              26              39            1851                    2
# 260600              21               9            9101                    3
#
# ...

# %%
train.to_csv('../Train/train_set_geo_level_sum_base_area_per_height.csv', index=False)
