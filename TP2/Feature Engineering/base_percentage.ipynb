# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Train

# %% [markdown]
# float

# %%
train = pd.read_csv('../Train/train_set_geo_level_sum.csv')

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train['base_percentage'] = train['area_percentage'] / train['height_percentage']

train['base_percentage'].value_counts()
# Out:
# 1.000000     33215
# 2.000000     15814
# 1.200000     14450
# 1.500000     13320
# 1.400000     12147
#              ...
# 0.680000         1
# 6.875000         1
# 19.250000        1
# 15.400000        1
# 2.764706         1
# Name: base_percentage, Length: 511, dtype: int64

# %%
cols = list(train.columns)
cols.remove('damage_grade')
cols.append('damage_grade')

train = train[cols]

train
# Out:
#         geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                    6             487           12198                    2
# 1                    8             900            2812                    2
# 2                   21             363            8973                    2
# 3                   22             418           10694                    2
# 4                   11             131            1488                    3
# ...                ...             ...             ...                  ...
# 260596              25            1335            1621                    1
# 260597              17             715            2060                    2
# 260598              17              51            8163                    3
# 260599              26              39            1851                    2
# 260600              21               9            9101                    3
#
# ...

# %%
train.to_csv('../Train/train_set_geo_level_sum_base.csv', index=False)

# %% [markdown]
# int

# %%
train = pd.read_csv('../Train/train_set_geo_level_sum.csv')

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train['base_percentage'] = train['area_percentage'] // train['height_percentage']

train['base_percentage'].value_counts()
# Out:
# 1     149349
# 0      46592
# 2      42941
# 3      12494
# 4       4635
# 5       2361
# 6       1008
# 7        509
# 8        271
# 9        179
# 11        67
# 10        60
# 12        39
# 13        19
# 14        18
# 15        11
# 16        11
# 17        11
# 21         7
# 19         4
# 22         4
# 18         3
# 27         2
# 28         2
# 23         1
# 24         1
# 25         1
# 30         1
# Name: base_percentage, dtype: int64

# %%
cols = list(train.columns)
cols.remove('damage_grade')
cols.append('damage_grade')

train = train[cols]

train
# Out:
#         geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                    6             487           12198                    2
# 1                    8             900            2812                    2
# 2                   21             363            8973                    2
# 3                   22             418           10694                    2
# 4                   11             131            1488                    3
# ...                ...             ...             ...                  ...
# 260596              25            1335            1621                    1
# 260597              17             715            2060                    2
# 260598              17              51            8163                    3
# 260599              26              39            1851                    2
# 260600              21               9            9101                    3
#
# ...

# %%
train.to_csv('../Train/train_set_geo_level_sum_base_int.csv', index=False)

# %% [markdown]
# ## Test

# %% [markdown]
# float

# %%
test = pd.read_csv('../Test/test_set_geo_level_sum.csv')

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test['base_percentage'] = test['area_percentage'] / test['height_percentage']

test['base_percentage'].value_counts()
# Out:
# 1.000000     11020
# 2.000000      5382
# 1.200000      4834
# 1.500000      4507
# 1.400000      4176
#              ...
# 11.800000        1
# 7.428571         1
# 2.363636         1
# 0.156250         1
# 2.181818         1
# Name: base_percentage, Length: 370, dtype: int64

# %%
test.to_csv('../Test/test_set_geo_level_sum_base.csv', index=False)

# %% [markdown]
# int

# %%
test = pd.read_csv('../Test/test_set_geo_level_sum.csv')

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test['base_percentage'] = test['area_percentage'] // test['height_percentage']

test['base_percentage'].value_counts()
# Out:
# 1.000000     11020
# 2.000000      5382
# 1.200000      4834
# 1.500000      4507
# 1.400000      4176
#              ...
# 11.800000        1
# 7.428571         1
# 2.363636         1
# 0.156250         1
# 2.181818         1
# Name: base_percentage, Length: 370, dtype: int64

# %%
test.to_csv('../Test/test_set_geo_level_sum_base_int.csv', index=False)
