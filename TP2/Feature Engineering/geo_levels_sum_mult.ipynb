# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Train

# %% [markdown]
# geo level sum

# %%
train = pd.read_csv('../Train/train_set_geo_level_sum.csv')

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
pos = len(train.columns) - 1

train.insert(pos, "geo_level_sum", train['geo_level_1_id'] + train['geo_level_2_id'] + train['geo_level_3_id'])

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train.insert(pos, "geo_level_multiply", train['geo_level_1_id'] * train['geo_level_2_id'] * train['geo_level_3_id'])

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train.to_csv('../Train/train_set_geo_levels_sum_mult.csv', index=False)

# %% [markdown]
# one hot encoding

# %%
train = pd.read_csv('../Train/train_set_one_hot_encoding_geo_level_sum.csv')

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
pos = len(train.columns) - 1

train.insert(pos, "geo_level_sum", train['geo_level_1_id'] + train['geo_level_2_id'] + train['geo_level_3_id'])

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train.insert(pos, "geo_level_multiply", train['geo_level_1_id'] * train['geo_level_2_id'] * train['geo_level_3_id'])

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
train.to_csv('../Train/train_set_one_hot_encoding_geo_levels_sum_mult.csv', index=False)

# %% [markdown]
# ## Test

# %% [markdown]
# geo level sum

# %%
test = pd.read_csv('../Test/test_set_geo_level_sum.csv')

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test['geo_level_sum'] = test['geo_level_1_id'] + test['geo_level_2_id'] + test['geo_level_3_id']

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test["geo_level_multiply"] = test['geo_level_1_id'] * test['geo_level_2_id'] * test['geo_level_3_id']

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test.to_csv('../Test/test_set_geo_levels_sum_mult.csv', index=False)

# %% [markdown]
# one hot encoding

# %%
test = pd.read_csv('../Test/test_set_one_hot_encoding_geo_level_sum.csv')

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
pos = len(test.columns) - 1

test.insert(pos, "geo_level_sum", test['geo_level_1_id'] + test['geo_level_2_id'] + test['geo_level_3_id'])

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test.insert(pos, "geo_level_multiply", test['geo_level_1_id'] * test['geo_level_2_id'] * test['geo_level_3_id'])

test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                             0                                    1  ...
# ...

# %%
test.to_csv('../Test/test_set_one_hot_encoding_geo_levels_sum_mult.csv', index=False)
