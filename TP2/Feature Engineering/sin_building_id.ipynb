# %%
import pandas as pd

# %%
train_set = pd.read_csv('../Train/train_set_original.csv')

train_set.head(10)
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
# 5       333020               8             558            6089
# 6       728451               9             475           12066
# 7       475515              20             323           12236
# 8       441126               0             757            7219
# 9       989500              26             886             994
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# ...

# %%
train_set.drop('building_id', axis='columns', inplace=True)

train_set.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage land_surface_condition foundation_type  \
# 0                6                  5                      t               r
# 1                8                  7                      o               r
# 2                5                  5                      t               r
# 3                6                  5                      t               r
# 4                8                  9                      t               r
#
# ...

# %%
train_set.to_csv("../Train/train_set_sin_building_id.csv", index=False)

# %%
test_set = pd.read_csv('../Test/test_values.csv')

test_set.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %%
test_set.drop('building_id', axis='columns', inplace=True)

test_set.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0              17             596           11307                    3   20
# 1               6             141           11987                    2   25
# 2              22              19           10044                    2    5
# 3              26              39             633                    1    0
# 4              17             289            7970                    3   15
#
#    area_percentage  height_percentage land_surface_condition foundation_type  \
# 0                7                  6                      t               r
# 1               13                  5                      t               r
# 2                4                  5                      t               r
# 3               19                  3                      t               r
# 4                8                  7                      t               r
#
# ...

# %%
test_set.to_csv("../Test/test_set_sin_building_id.csv", index=False)
