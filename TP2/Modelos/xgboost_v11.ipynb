# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv('../Train/train_set_geo_floors_age_sum.csv')

train.head()
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
#
#    area_percentage  height_percentage  has_superstructure_adobe_mud  \
# 0                6                  5                             1
# 1                8                  7                             0
# 2                5                  5                             0
# 3                6                  5                             0
# 4                8                  9                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  ...  \
# ...

# %%
X, y = train.iloc[:,:-1], train.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xgb_model = xgb.XGBClassifier(n_estimators=5, max_depth=15, learning_rate=0.01, random_state=123, gamma=0, reg_lambda=0.4, verbosity=0)
xgb_model.fit(X_train, y_train)
preds = xgb_model.predict(X_test)
f1 = f1_score(y_test, preds, average='micro'),
print("F1-Mean Score %f" % (f1))
# Out:
# [10:05:25] ======== Monitor: Learner ========
# [10:05:25] Configure: 0.000175s, 1 calls @ 175us
#
# [10:05:25] ======== Monitor: GBTree ========
# [10:05:25] ======== Monitor: TreePruner ========
# /home/ben/.local/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# F1-Mean Score 0.719652

# %%
xgb_model = xgb.XGBClassifier(n_estimators=30, max_depth=30, learning_rate=0.3, random_state=123, gamma=4.5, reg_lambda=3.5, verbosity=0)
xgb_model.fit(X_train, y_train)
preds = xgb_model.predict(X_test)
f1 = f1_score(y_test, preds, average='micro'),
print("F1-Mean Score %f" % (f1))
# Out:
# /home/ben/.local/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# F1-Mean Score 0.737994

# %%
params = {
    'n_estimators': [5, 15, 30],
    'max_depth': [15, 30],
    'learning_rate': [0.01, 0.1, 0.3],
    'random_state': [123],
    'gamma': [0, 1.5, 4.5],
    'reg_lambda': [0.4, 1.3, 3.5]
}

# %%
opt = GridSearchCV(xgb.XGBClassifier(), params, cv=10)
opt.fit(X_train, y_train)
# Out:
# /home/ben/.local/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:06:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
opt.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-48290f2f8b8f> in <module>
# ----> 1 opt.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
preds = opt.predict(X_test)
f1 = f1_score(y_test, preds, average='micro'),
print("F1-Mean Score %f" % (f1))
